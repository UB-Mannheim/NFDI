# %% [markdown]
# # Quick start: Module `data`
#
# The module `data` stores raw data.

# %%
from nfdi import data
data.raw
# Out:
# {'BERD@NFDI': {'GEPRIS': 'http://gepris.dfg.de/gepris/projekt/460037581',
#   'GitHub': '',
#   'Homepage': 'https://www.berd-nfdi.de',
#   'Inception': '2021-10-01T00:00:00Z',
#   'Twitter': 'https://twitter.com/BERD_NFDI',
#   'Wikidata': 'http://www.wikidata.org/entity/Q108542181',
#   'Zenodo': '',
#   'Linkedin': 'https://www.linkedin.com/company/berd-nfdi'},
#  'DAPHNE4NFDI': {'GEPRIS': 'http://gepris.dfg.de/gepris/projekt/460248799',
#   'GitHub': '',
#   'Homepage': 'http://www.daphne-nfdi.de',
#   'Inception': '2021-10-01T00:00:00Z',
#   'Twitter': '',
#   'Wikidata': 'http://www.wikidata.org/entity/Q108542327',
#   'YouTube': '',
#   'Zenodo': ''},
#  'DataPlant': {'GEPRIS': 'http://gepris.dfg.de/gepris/projekt/442077441',
#   'GitHub': 'https://github.com/nfdi4plants',
#   'Homepage': 'http://nfdi4plants.de',
#   'Inception': '2020-10-01T00:00:00Z',
#   'Twitter': 'https://twitter.com/nfdi4plants',
#   'Wikidata': 'http://www.wikidata.org/entity/Q98380336',
# ...
