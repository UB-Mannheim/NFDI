# %% [markdown]
# # Parsing GEPRIS pages of NFDI consortia for project applicants and participants
# The list of funded NFDI projects with their GEPRIS IDs was saved in the notebook 02. Let's read that file into a dataframe.

# %%
import pandas as pd
df = pd.read_csv("../../../data/GEPRIS_NFDI_all.csv").fillna('')
df
# Out:
#                                             GEPRIS              Title  \
# 0   https://gepris.dfg.de/gepris/projekt/441914366               GHGA
# 1   https://gepris.dfg.de/gepris/projekt/441926934           NFDI4Cat
# 2   https://gepris.dfg.de/gepris/projekt/441958017       NFDI4Culture
# 3   https://gepris.dfg.de/gepris/projekt/441958208          NFDI4Chem
# 4   https://gepris.dfg.de/gepris/projekt/442032008  NFDI4BioDiversity
# 5   https://gepris.dfg.de/gepris/projekt/442077441          DataPLANT
# 6   https://gepris.dfg.de/gepris/projekt/442146713           NFDI4Ing
# 7   https://gepris.dfg.de/gepris/projekt/442326535        NFDI4Health
# 8   https://gepris.dfg.de/gepris/projekt/442494171         KonsortSWD
# 9   https://gepris.dfg.de/gepris/projekt/460033370              Text+
# 10  https://gepris.dfg.de/gepris/projekt/460036893         NFDI4Earth
# 11  https://gepris.dfg.de/gepris/projekt/460037581          BERD@NFDI
# 12  https://gepris.dfg.de/gepris/projekt/460129525    NFDI4Microbiota
# 13  https://gepris.dfg.de/gepris/projekt/460135501              MaRDI
# 14  https://gepris.dfg.de/gepris/projekt/460197019            FAIRmat
# 15  https://gepris.dfg.de/gepris/projekt/460234259            NFDI4DS
# 16  https://gepris.dfg.de/gepris/projekt/460247524       NFDI-MatWerk
# 17  https://gepris.dfg.de/gepris/projekt/460248186         PUNCH4NFDI
# 18  https://gepris.dfg.de/gepris/projekt/460248799        DAPHNE4NFDI
#
#                                           Description
# 0                 German Human Genome-Phenome Archive
# 1                 NFDI for Catalysis-Related Sciences
# 2   Consortium for research data on material and i...
# 3                    Chemistry Consortium in the NFDI
# 4          Biodiversity, Ecology & Environmental Data
# 5                              Data in PLANT research
# 6   National Research Data Infrastructure for Engi...
# 7   National Research Data Infrastructure for Pers...
# 8   Consortium for the Social, Behavioural, Educat...
# 9
# 10              NFDI Consortium Earth System Sciences
# 11       NFDI for Business, Economic and Related Data
# 12  National Research Data Infrastructure for Micr...
# 13              Mathematical Research Data Initiative
# 14  FAIR Data Infrastructure for Condensed-Matter ...
# 15  NFDI for Data Science and Artificial Intelligence
# 16  National Research Data Infrastructure for Mate...
# 17  Particles, Universe, NuClei and Hadrons for th...
# 18  DAta from PHoton and Neutron Experiments for NFDI

# %% [markdown]
# For testing let's start with BERD@BW consortium only.

# %%
import requests
GEPRIS = "https://gepris.dfg.de/gepris/projekt/460037581"
params = {'language': 'en'}
r = requests.get(GEPRIS, params=params)
text = r.text.encode(r.encoding).decode('utf8')
print(text[0:100].strip())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"
#     "http://www

# %% [markdown]
# Then the subject area is parsed:

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(text, 'html.parser')
results = soup.find_all("div", class_="firstUnderAntragsbeteiligte")
subject_area = results[0].find_all('span')[-1].text.strip().replace('  ', '').replace('\n', ', ')
print(subject_area)
# Out:
# Social and Behavioural Sciences

# %% [markdown]
# The homepage is parsed:

# %%
try:
    homepage = soup.find('a', class_="extern").get('href')
except:
    homepage = ''
print(homepage)

# %% [markdown]
# The project description is parsed:

# %%
description = soup.find('div', id="projekttext").text.strip()
print(description)
# Out:
# The research domains of business, economics, and other social sciences are concerned with the relationships among individuals and organizations within a society. To understand these complex systems, social science disciplines have been using empirical methods for a long time. However, unstructured and non-standard data, i.e., information that either does not have a previously defined data model or is not organized in a predefined manner (e.g., images or videos from social media), are gaining in relevance. The generation of continuous data streams in society and economy (datafication) strengthens this trend: It is estimated that by 2025 80% of the data processed in economic applications will be available in unstructured form. Because of the sheer size and, more importantly, the lack of structure and the heterogeneity of raw digital data, the BERD@NFDI community calls for innovative and reusable methods, mostly from artificial intelligence and machine learning, as well as a suitable storage and computing environment to process the data in a way that it can be used for further scientific analyses. Consequently, algorithms become an integral part of the research data life cycle and thus have to be managed in the same way as the data itself.Within this context, the mission of BERD@NFDI is to develop, provide, and maintain a future-oriented, powerful research data infrastructure for the integrated management of unstructured data and related scientific software. With this focus and a clear commitment to openness (e.g., open software, open standards) BERD@NFDI can be an important and unique mosaic stone to build up the NFDI.BERD@NFDI will coordinate and enable sustainable research processes through the ongoing design of suitable services. It will not provide a mere storage location for data and scientific software, but a service portfolio that will be strictly aligned to the actual needs of the scientific user community. User feedback will be ensured through the BERD@NFDI training program, technically integrated interaction features, and institutionalized user participation in the consortium's committee structure.The consortium is headed by the University of Mannheim and is composed of seven co-applicant institutions including infrastructure providers and research institutions with a focus on business, economics, and other social sciences. Many of them have a long-lasting tradition of prosperous collaboration, which leverages the consortium to a high level of efficiency and effectiveness to successfully conduct the ambitious work program. Finally, the transparent governance structure with clear responsibilities together with a user-centric, multi-stakeholder approach will ensure the success of BERD@NFDI and will make a structural contribution to the success of the NFDI as a whole.

# %% [markdown]
# Let's parse the rest of useful data, put it into `berd` dictionary and pretty print it:

# %%
s = soup.find_all('div', class_="content_frame")
berd = {}
for k in s[1].find_all('div'):
    try:
        t = k.find('span', class_="name")
        if t.get_text().strip()!="DFG Programme" and k.find_all('a', class_="intern"):
            berd[t.get_text().strip()] = [ (g.get_text(), "https://gepris.dfg.de" + g.get('href')) for g in k.find_all('a', class_="intern")]
    except:
        pass
from pprint import pprint
pprint(berd)
# Out:
# {'Applying institution': [('Universität Mannheim',
#                            'https://gepris.dfg.de/gepris/institution/10045')],
#  'Co-Spokespersons': [('Professor Dr. Bernd  Bischl',
#                        'https://gepris.dfg.de/gepris/person/289708818'),
#                       ('Professor Dr. Stefan  Dietze',
#                        'https://gepris.dfg.de/gepris/person/218646654'),
#                       ('Professor Dr. Marc  Fischer',
#                        'https://gepris.dfg.de/gepris/person/1804971'),
#                       ('Dr. Sabine  Gehrlein',
#                        'https://gepris.dfg.de/gepris/person/398007310'),
#                       ('Professor Dr. Mark  Heitmann',
#                        'https://gepris.dfg.de/gepris/person/216564778'),
#                       ('Professor Dr. Hartmut  Höhle',
#                        'https://gepris.dfg.de/gepris/person/442455860'),
#                       ('Professor Dr. Göran  Kauermann',
#                        'https://gepris.dfg.de/gepris/person/1375171'),
#                       ('Professorin Dr. Frauke  Kreuter',
#                        'https://gepris.dfg.de/gepris/person/1755279'),
#                       ('Professor Dr. Klaus  Tochtermann',
#                        'https://gepris.dfg.de/gepris/person/1552555'),
#                       ('Professor Dr. Christof  Wolf',
#                        'https://gepris.dfg.de/gepris/person/1610376')],
#  'Co-applicant institution': [('GESIS - Leibniz-Institut für '
#                                'Sozialwissenschaften',
#                                'https://gepris.dfg.de/gepris/institution/145000415'),
#                               ('Institut für Arbeitsmarkt- und Berufsforschung '
#                                '(IAB)der Bundesagentur für Arbeit (BA)',
#                                'https://gepris.dfg.de/gepris/institution/12925'),
#                               ('Ludwig-Maximilians-Universität München',
#                                'https://gepris.dfg.de/gepris/institution/10108'),
#                               ('Universität Hamburg',
#                                'https://gepris.dfg.de/gepris/institution/10192'),
#                               ('Universität zu Köln',
#                                'https://gepris.dfg.de/gepris/institution/10282'),
#                               ('ZBW - Leibniz-Informationszentrum Wirtschaft',
#                                'https://gepris.dfg.de/gepris/institution/17916')],
#  'Cooperation partners': [('Professor Rayid  Ghani',
#                            'https://gepris.dfg.de/gepris/person/406699457'),
#                           ('Professorin Dr. Julia  Lane',
#                            'https://gepris.dfg.de/gepris/person/442458155')],
#  'Participating Institution': [('Bayerische Akademie der Wissenschaften',
#                                 'https://gepris.dfg.de/gepris/institution/10138'),
#                                ('Gesellschaft für Sozial- und '
#                                 'Wirtschaftsgeschichte e. V.c/o Universität '
#                                 'RegensburgLehrstuhl für Wirtschafts- und '
#                                 'Sozialgeschichte',
#                                 'https://gepris.dfg.de/gepris/institution/442499111'),
#                                ('Gesellschaft für Unternehmensgeschichte e.V. '
#                                 '(GUG)',
#                                 'https://gepris.dfg.de/gepris/institution/442499393'),
#                                ('Institut für Bank- und Finanzgeschichte e.V. '
#                                 '(IBF)',
#                                 'https://gepris.dfg.de/gepris/institution/442499747'),
#                                ('Leibniz-Institut für Finanzmarktforschung '
#                                 'SAFE',
#                                 'https://gepris.dfg.de/gepris/institution/263945553'),
#                                ('Leibniz-Institut für ökologische '
#                                 'Raumentwicklung (IÖR) e.V.',
#                                 'https://gepris.dfg.de/gepris/institution/10398'),
#                                ('Rat für Sozial- und Wirtschaftsdaten '
#                                 '(RatSWD)c/o Wissenschaftszentrum Berlin (WZB)',
#                                 'https://gepris.dfg.de/gepris/institution/310279050'),
#                                ('Verband der Hochschullehrer für '
#                                 'Betriebswirtschaft (VHB) e.V.',
#                                 'https://gepris.dfg.de/gepris/institution/233943626'),
#                                ('Verein für Socialpolitik',
#                                 'https://gepris.dfg.de/gepris/institution/428818528'),
#                                ('ZEW - Leibniz-Zentrum für Europäische '
#                                 'Wirtschaftsforschung GmbH',
#                                 'https://gepris.dfg.de/gepris/institution/10543')],
#  'Participating Persons': [('Dr. Marianne  Dörr',
#                             'https://gepris.dfg.de/gepris/person/60331789'),
#                            ('Dr. Fabian  Franke',
#                             'https://gepris.dfg.de/gepris/person/96294761'),
#                            ('Dr. Katrin  Moeller',
#                             'https://gepris.dfg.de/gepris/person/236205840'),
#                            ('Dana  Müller',
#                             'https://gepris.dfg.de/gepris/person/350461336'),
#                            ('Professorin Dr. Isabella  Peters',
#                             'https://gepris.dfg.de/gepris/person/59860187'),
#                            ('Alexander  Pfister',
#                             'https://gepris.dfg.de/gepris/person/442456395'),
#                            ('Professor Dr. Mark  Spoerer',
#                             'https://gepris.dfg.de/gepris/person/1857714'),
#                            ('Professor Dr. Jochen  Streb',
#                             'https://gepris.dfg.de/gepris/person/1631070'),
#                            ('Professor Dr. Heiner  Stuckenschmidt',
#                             'https://gepris.dfg.de/gepris/person/1670080'),
#                            ('Dr. Peter  Wittenburg',
#                             'https://gepris.dfg.de/gepris/person/219421514')],
#  'Spokesperson': [('Professor Dr. Florian  Stahl',
#                    'https://gepris.dfg.de/gepris/person/274347517')]}

# %% [markdown]
# Now we can loop over all consortia and get that data about them automatically:

# %%
nfdi = {}
for GEPRIS, title in zip(df['GEPRIS'],df['Title']):
    nfdi[GEPRIS] = {}
    nfdi[GEPRIS]['title'] = title
    params = {'language': 'en'}
    r = requests.get(GEPRIS, params=params)
    text = r.text.encode(r.encoding).decode('utf8')
    soup = BeautifulSoup(text, 'html.parser')
    results = soup.find_all("div", class_="firstUnderAntragsbeteiligte")
    subject_area = results[0].find_all('span')[-1].text.strip().replace('  ', '').replace('\n', ', ')
    nfdi[GEPRIS]['subject_area'] = subject_area
    try:
        homepage = soup.find('a', class_="extern").get('href')
    except:
        homepage = ''
    nfdi[GEPRIS]['homepage'] = homepage
    description = soup.find('div', id="projekttext").text.strip()
    nfdi[GEPRIS]['description'] = description
    s = soup.find_all('div', class_="content_frame")
    for k in s[1].find_all('div'):
        try:
            t = k.find('span', class_="name")
            if t.get_text().strip()!="DFG Programme" and k.find_all('a', class_="intern"):
                nfdi[GEPRIS][t.get_text().strip()] = [ (g.get_text(), "https://gepris.dfg.de" + g.get('href')) for g in k.find_all('a', class_="intern")]
        except:
            pass
import pandas as pd
df_nfdi = pd.DataFrame(nfdi).fillna('')
df_nfdi.T
# Out:
#                                                             title  \
# https://gepris.dfg.de/gepris/projekt/441914366               GHGA
# https://gepris.dfg.de/gepris/projekt/441926934           NFDI4Cat
# https://gepris.dfg.de/gepris/projekt/441958017       NFDI4Culture
# https://gepris.dfg.de/gepris/projekt/441958208          NFDI4Chem
# https://gepris.dfg.de/gepris/projekt/442032008  NFDI4BioDiversity
# https://gepris.dfg.de/gepris/projekt/442077441          DataPLANT
# https://gepris.dfg.de/gepris/projekt/442146713           NFDI4Ing
# https://gepris.dfg.de/gepris/projekt/442326535        NFDI4Health
# https://gepris.dfg.de/gepris/projekt/442494171         KonsortSWD
# https://gepris.dfg.de/gepris/projekt/460033370              Text+
# https://gepris.dfg.de/gepris/projekt/460036893         NFDI4Earth
# https://gepris.dfg.de/gepris/projekt/460037581          BERD@NFDI
# https://gepris.dfg.de/gepris/projekt/460129525    NFDI4Microbiota
# https://gepris.dfg.de/gepris/projekt/460135501              MaRDI
# https://gepris.dfg.de/gepris/projekt/460197019            FAIRmat
# https://gepris.dfg.de/gepris/projekt/460234259            NFDI4DS
# https://gepris.dfg.de/gepris/projekt/460247524       NFDI-MatWerk
# https://gepris.dfg.de/gepris/projekt/460248186         PUNCH4NFDI
# https://gepris.dfg.de/gepris/projekt/460248799        DAPHNE4NFDI
#
#                                                                                      subject_area  \
# https://gepris.dfg.de/gepris/projekt/441914366                                  Medicine, Biology
# https://gepris.dfg.de/gepris/projekt/441926934  Biology, Chemistry, Mathematics, Thermal Engin...
# https://gepris.dfg.de/gepris/projekt/441958017  Humanities, Construction Engineering and Archi...
# https://gepris.dfg.de/gepris/projekt/441958208                                          Chemistry
# https://gepris.dfg.de/gepris/projekt/442032008  Biology, Medicine, Agriculture, Forestry and V...
# https://gepris.dfg.de/gepris/projekt/442077441                                            Biology
# https://gepris.dfg.de/gepris/projekt/442146713  Mechanical and Industrial Engineering, Thermal...
# https://gepris.dfg.de/gepris/projekt/442326535                                           Medicine
# https://gepris.dfg.de/gepris/projekt/442494171        Social and Behavioural Sciences, Humanities
# https://gepris.dfg.de/gepris/projekt/460033370                                         Humanities
# https://gepris.dfg.de/gepris/projekt/460036893  Geosciences, Agriculture, Forestry and Veterin...
# https://gepris.dfg.de/gepris/projekt/460037581                    Social and Behavioural Sciences
# https://gepris.dfg.de/gepris/projekt/460129525                                            Biology
# https://gepris.dfg.de/gepris/projekt/460135501                                        Mathematics
# https://gepris.dfg.de/gepris/projekt/460197019                                            Physics
# https://gepris.dfg.de/gepris/projekt/460234259  Computer Science, Systems andElectrical Engine...
# https://gepris.dfg.de/gepris/projekt/460247524                  Materials Science and Engineering
# https://gepris.dfg.de/gepris/projekt/460248186                                            Physics
# https://gepris.dfg.de/gepris/projekt/460248799  Physics, Biology, Chemistry, Materials Science...
#
#                                                                          homepage  \
# https://gepris.dfg.de/gepris/projekt/441914366              https://ghga.dkfz.de/
# https://gepris.dfg.de/gepris/projekt/441926934    http://gecats.org/NFDI4Cat.html
# https://gepris.dfg.de/gepris/projekt/441958017            https://nfdi4culture.de
# https://gepris.dfg.de/gepris/projekt/441958208               https://nfdi4chem.de
# https://gepris.dfg.de/gepris/projekt/442032008  https://www.nfdi4biodiversity.org
# https://gepris.dfg.de/gepris/projekt/442077441             https://nfdi4plants.de
# https://gepris.dfg.de/gepris/projekt/442146713                https://nfdi4ing.de
# https://gepris.dfg.de/gepris/projekt/442326535         https://www.nfdi4health.de
# https://gepris.dfg.de/gepris/projekt/442494171          https://www.konsortswd.de
# https://gepris.dfg.de/gepris/projekt/460033370
# https://gepris.dfg.de/gepris/projekt/460036893
# https://gepris.dfg.de/gepris/projekt/460037581
# https://gepris.dfg.de/gepris/projekt/460129525
# https://gepris.dfg.de/gepris/projekt/460135501
# https://gepris.dfg.de/gepris/projekt/460197019
# https://gepris.dfg.de/gepris/projekt/460234259
# https://gepris.dfg.de/gepris/projekt/460247524
# https://gepris.dfg.de/gepris/projekt/460248186
# https://gepris.dfg.de/gepris/projekt/460248799
#
#                                                                                       description  \
# https://gepris.dfg.de/gepris/projekt/441914366  Human genome sequencing and other omics data m...
# https://gepris.dfg.de/gepris/projekt/441926934  The overall strategy for the transformation of...
# https://gepris.dfg.de/gepris/projekt/441958017  Digital data on tangible and intangible cultur...
# https://gepris.dfg.de/gepris/projekt/441958208  The vision of NFDI4Chem is the digitalisation ...
# https://gepris.dfg.de/gepris/projekt/442032008  Biodiversity is more than just the diversity o...
# https://gepris.dfg.de/gepris/projekt/442077441  In modern hypothesis-driven research, scientis...
# https://gepris.dfg.de/gepris/projekt/442146713  NFDI4Ing brings together the engineering commu...
# https://gepris.dfg.de/gepris/projekt/442326535  Germany has accumulated a wealth of health-rel...
# https://gepris.dfg.de/gepris/projekt/442494171  The social, behavioural, educational, and econ...
# https://gepris.dfg.de/gepris/projekt/460033370  Text+ aims to develop a research data infrastr...
# https://gepris.dfg.de/gepris/projekt/460036893  NFDI4Earth addresses digital needs of Earth Sy...
# https://gepris.dfg.de/gepris/projekt/460037581  The research domains of business, economics, a...
# https://gepris.dfg.de/gepris/projekt/460129525  Microbes – bacteria, archaea, unicellular euka...
# https://gepris.dfg.de/gepris/projekt/460135501  Mathematical research data (MRD) has become va...
# https://gepris.dfg.de/gepris/projekt/460197019  Scientific data are a significant raw material...
# https://gepris.dfg.de/gepris/projekt/460234259  The vision of NFDI4DataScience (NFDI4DS) is to...
# https://gepris.dfg.de/gepris/projekt/460247524  Since the Stone Age the mastery of materials h...
# https://gepris.dfg.de/gepris/projekt/460248186  PUNCH4NFDI, the consortium of particle, astrop...
# https://gepris.dfg.de/gepris/projekt/460248799  The photon and neutron science community encom...
#
#                                                                              Applying institution  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(Deutsches Krebsforschungszentrum (DKFZ), htt...
# https://gepris.dfg.de/gepris/projekt/441926934  [(DECHEMA Gesellschaft für Chemische Technik u...
# https://gepris.dfg.de/gepris/projekt/441958017  [(Akademie der Wissenschaften und der Literatu...
# https://gepris.dfg.de/gepris/projekt/441958208  [(Friedrich-Schiller-Universität Jena, https:/...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Universität Bremen, https://gepris.dfg.de/ge...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Albert-Ludwigs-Universität Freiburg, https:/...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Rheinisch-Westfälische Technische Hochschule...
# https://gepris.dfg.de/gepris/projekt/442326535  [(Deutsche Zentralbibliothek für Medizin (ZB M...
# https://gepris.dfg.de/gepris/projekt/442494171  [(GESIS - Leibniz-Institut für Sozialwissensch...
# https://gepris.dfg.de/gepris/projekt/460033370  [(Leibniz-Institut für Deutsche Sprache (IDS),...
# https://gepris.dfg.de/gepris/projekt/460036893  [(Technische Universität Dresden, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460037581  [(Universität Mannheim, https://gepris.dfg.de/...
# https://gepris.dfg.de/gepris/projekt/460129525  [(Deutsche Zentralbibliothek für Medizin (ZB M...
# https://gepris.dfg.de/gepris/projekt/460135501  [(Weierstraß-Institut für Angewandte Analysis ...
# https://gepris.dfg.de/gepris/projekt/460197019  [(Humboldt-Universität zu Berlin, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Fraunhofer-Gesellschaft zur Förderung der an...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Fraunhofer-Gesellschaft zur Förderung der an...
# https://gepris.dfg.de/gepris/projekt/460248186  [(Deutsches Elektronen-Synchrotron (DESY), htt...
# https://gepris.dfg.de/gepris/projekt/460248799  [(Deutsches Elektronen-Synchrotron (DESY), htt...
#
#                                                                          Co-applicant institution  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(Charité - Universitätsmedizin Berlin, https:...
# https://gepris.dfg.de/gepris/projekt/441926934  [(Fraunhofer-Institut für Offene Kommunikation...
# https://gepris.dfg.de/gepris/projekt/441958017  [(FIZ KarlsruheLeibniz-Institut für Informatio...
# https://gepris.dfg.de/gepris/projekt/441958208  [(FIZ KarlsruheLeibniz-Institut für Informatio...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Forschungsinstitut für Nutztierbiologie (FBN...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Eberhard Karls Universität Tübingen, https:/...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Deutsches Zentrum für Luft- und Raumfahrt e....
# https://gepris.dfg.de/gepris/projekt/442326535  [(Charité - Universitätsmedizin Berlin, https:...
# https://gepris.dfg.de/gepris/projekt/442494171  [(Deutsches Institut für Wirtschaftsforschung ...
# https://gepris.dfg.de/gepris/projekt/460033370  [(Berlin-Brandenburgische Akademie der Wissens...
# https://gepris.dfg.de/gepris/projekt/460036893  [(Alfred-Wegener-InstitutHelmholtz-Zentrum für...
# https://gepris.dfg.de/gepris/projekt/460037581  [(GESIS - Leibniz-Institut für Sozialwissensch...
# https://gepris.dfg.de/gepris/projekt/460129525  [(European Molecular Biology Laboratory (EMBL)...
# https://gepris.dfg.de/gepris/projekt/460135501  [(Deutsche Mathematiker-Vereinigung e.V.c/o WI...
# https://gepris.dfg.de/gepris/projekt/460197019  [(FAIR-DI e.V.Humboldt-Universität zu Berlin, ...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Deutsche Zentralbibliothek für Medizin (ZB M...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Deutsches Forschungszentrum für Künstliche I...
# https://gepris.dfg.de/gepris/projekt/460248186  [(Forschungszentrum Jülich, https://gepris.dfg...
# https://gepris.dfg.de/gepris/projekt/460248799  [(Bergische Universität Wuppertal, https://gep...
#
#                                                                         Participating Institution  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(CISPA - Helmholtz-Zentrum für Informationssi...
# https://gepris.dfg.de/gepris/projekt/441926934  [(Technische Universität Darmstadt, https://ge...
# https://gepris.dfg.de/gepris/projekt/441958017  [(Arbeitsgemeinschaft der kunsthistorischen Bi...
# https://gepris.dfg.de/gepris/projekt/441958208  [(Beilstein-Institut zur Förderung der chemisc...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Alfred-Wegener-InstitutHelmholtz-Zentrum für...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Helmholtz Zentrum München - Deutsches Forsch...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Bundesanstalt für Materialforschung und -prü...
# https://gepris.dfg.de/gepris/projekt/442326535  [(Behörde für Gesundheit und Verbraucherschutz...
# https://gepris.dfg.de/gepris/projekt/442494171  [(Bundesamt für Migration und Flüchtlinge, htt...
# https://gepris.dfg.de/gepris/projekt/460033370  [(Akademie der Wissenschaften in Hamburg, http...
# https://gepris.dfg.de/gepris/projekt/460036893  [(Bayerische Akademie der Wissenschaften, http...
# https://gepris.dfg.de/gepris/projekt/460037581  [(Bayerische Akademie der Wissenschaften, http...
# https://gepris.dfg.de/gepris/projekt/460129525  [(Christian-Albrechts-Universität zu Kiel, htt...
# https://gepris.dfg.de/gepris/projekt/460135501  [(European Mathematical Society, https://gepri...
# https://gepris.dfg.de/gepris/projekt/460197019  [(Deutsche Physikalische Gesellschaft e. V., h...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Alfred-Wegener-InstitutHelmholtz-Zentrum für...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Albert-Ludwigs-Universität Freiburg, https:/...
# https://gepris.dfg.de/gepris/projekt/460248186  [(Albert-Ludwigs-Universität Freiburg, https:/...
# https://gepris.dfg.de/gepris/projekt/460248799  [(Bruker AXS GmbH, https://gepris.dfg.de/gepri...
#
#                                                                                      Spokesperson  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(Professor Dr. Oliver  Stegle, Ph.D., https:/...
# https://gepris.dfg.de/gepris/projekt/441926934  [(Dr. Andreas  Förster, https://gepris.dfg.de/...
# https://gepris.dfg.de/gepris/projekt/441958017  [(Professor Torsten  Schrade, https://gepris.d...
# https://gepris.dfg.de/gepris/projekt/441958208  [(Professor Dr. Christoph  Steinbeck, https://...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Professor Dr. Frank Oliver  Glöckner, https:...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Dr. Dirk von Suchodoletz, https://gepris.dfg...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Professor Dr.-Ing. Robert  Schmitt, https://...
# https://gepris.dfg.de/gepris/projekt/442326535  [(Professorin Dr. Juliane  Fluck, https://gepr...
# https://gepris.dfg.de/gepris/projekt/442494171  [(Professor Dr. Christof  Wolf, https://gepris...
# https://gepris.dfg.de/gepris/projekt/460033370  [(Professor Dr. Erhard  Hinrichs, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460036893  [(Professor Dr. Lars  Bernard, https://gepris....
# https://gepris.dfg.de/gepris/projekt/460037581  [(Professor Dr. Florian  Stahl, https://gepris...
# https://gepris.dfg.de/gepris/projekt/460129525  [(Professor Dr. Konrad  Förstner, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460135501  [(Professor Dr. Michael  Hintermüller, https:/...
# https://gepris.dfg.de/gepris/projekt/460197019  [(Professorin Dr. Claudia  Draxl, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Dr. Sonja  Schimmler, https://gepris.dfg.de/...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Professor Dr. Christoph  Eberl, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460248186  [(Privatdozent Dr. Thomas  Schörner-Sadenius, ...
# https://gepris.dfg.de/gepris/projekt/460248799  [(Dr. Anton  Barty, https://gepris.dfg.de/gepr...
#
#                                                                             Participating Persons  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(Viktor  Achter, https://gepris.dfg.de/gepris...
# https://gepris.dfg.de/gepris/projekt/441926934  [(Professor Dr.-Ing. Bastian  Etzold, https://...
# https://gepris.dfg.de/gepris/projekt/441958017  [(Professorin Dr. Stefanie  Acquavella-Rauch, ...
# https://gepris.dfg.de/gepris/projekt/441958208  [(Privatdozent Dr. Carsten  Baldauf, https://g...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Professor Dr. Christian  Ammer, https://gepr...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Professor Dr. Rolf  Backofen, https://gepris...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Professorin Dr. Jasmin  Aghassi-Hagmann, htt...
# https://gepris.dfg.de/gepris/projekt/442326535  [(Professor Dr. Thomas  Behrens, https://gepri...
# https://gepris.dfg.de/gepris/projekt/442494171
# https://gepris.dfg.de/gepris/projekt/460033370  [(Professor Dr. Andreas  Henrich, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460036893
# https://gepris.dfg.de/gepris/projekt/460037581  [(Dr. Marianne  Dörr, https://gepris.dfg.de/ge...
# https://gepris.dfg.de/gepris/projekt/460129525
# https://gepris.dfg.de/gepris/projekt/460135501  [(Professor Dr. Peter  Bastian, https://gepris...
# https://gepris.dfg.de/gepris/projekt/460197019  [(Professor Dr. Martin  Aeschlimann, https://g...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Privatdozent Dr. Carsten  Baldauf, https://g...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Professor Dr.-Ing. Tilmann  Beck, https://ge...
# https://gepris.dfg.de/gepris/projekt/460248186
# https://gepris.dfg.de/gepris/projekt/460248799
#
#                                                                                  Co-Spokespersons  \
# https://gepris.dfg.de/gepris/projekt/441914366  [(Privatdozent Dr. Peer  Bork, https://gepris....
# https://gepris.dfg.de/gepris/projekt/441926934  [(Professor Dr. Matthias  Beller, https://gepr...
# https://gepris.dfg.de/gepris/projekt/441958017  [(Reinhard  Altenhöner, https://gepris.dfg.de/...
# https://gepris.dfg.de/gepris/projekt/441958208  [(Dr. Felix  Bach, https://gepris.dfg.de/gepri...
# https://gepris.dfg.de/gepris/projekt/442032008  [(Professorin Dr. Aletta  Bonn, https://gepris...
# https://gepris.dfg.de/gepris/projekt/442077441  [(Dr. Jens  Krüger, https://gepris.dfg.de/gepr...
# https://gepris.dfg.de/gepris/projekt/442146713  [(Verena  Anthofer, https://gepris.dfg.de/gepr...
# https://gepris.dfg.de/gepris/projekt/442326535  [(Professor Dr. Wolfgang  Ahrens, https://gepr...
# https://gepris.dfg.de/gepris/projekt/442494171  [(Dr. Maja  Adena, https://gepris.dfg.de/gepri...
# https://gepris.dfg.de/gepris/projekt/460033370  [(Privatdozent Dr. Alexander  Geyken, https://...
# https://gepris.dfg.de/gepris/projekt/460036893  [(Roland  Bertelmann, https://gepris.dfg.de/ge...
# https://gepris.dfg.de/gepris/projekt/460037581  [(Professor Dr. Bernd  Bischl, https://gepris....
# https://gepris.dfg.de/gepris/projekt/460129525  [(Professorin Dr. Anke  Becker, https://gepris...
# https://gepris.dfg.de/gepris/projekt/460135501  [(Professorin Dr. Ilka  Agricola, https://gepr...
# https://gepris.dfg.de/gepris/projekt/460197019  [(Dr. Martin  Albrecht, https://gepris.dfg.de/...
# https://gepris.dfg.de/gepris/projekt/460234259  [(Professor Dr. Ziawasch  Abedjan, https://gep...
# https://gepris.dfg.de/gepris/projekt/460247524  [(Professor Dr.-Ing. Erik  Bitzek, https://gep...
# https://gepris.dfg.de/gepris/projekt/460248186  [(Privatdozent Dr. Philip  Bechtle, https://ge...
# https://gepris.dfg.de/gepris/projekt/460248799  [(Dr. Sebastian  Busch, https://gepris.dfg.de/...
#
#                                                                              Cooperation partners
# https://gepris.dfg.de/gepris/projekt/441914366
# https://gepris.dfg.de/gepris/projekt/441926934
# https://gepris.dfg.de/gepris/projekt/441958017
# https://gepris.dfg.de/gepris/projekt/441958208
# https://gepris.dfg.de/gepris/projekt/442032008
# https://gepris.dfg.de/gepris/projekt/442077441
# https://gepris.dfg.de/gepris/projekt/442146713
# https://gepris.dfg.de/gepris/projekt/442326535
# https://gepris.dfg.de/gepris/projekt/442494171
# https://gepris.dfg.de/gepris/projekt/460033370
# https://gepris.dfg.de/gepris/projekt/460036893
# https://gepris.dfg.de/gepris/projekt/460037581  [(Professor Rayid  Ghani, https://gepris.dfg.d...
# https://gepris.dfg.de/gepris/projekt/460129525
# https://gepris.dfg.de/gepris/projekt/460135501
# https://gepris.dfg.de/gepris/projekt/460197019
# https://gepris.dfg.de/gepris/projekt/460234259
# https://gepris.dfg.de/gepris/projekt/460247524
# https://gepris.dfg.de/gepris/projekt/460248186
# https://gepris.dfg.de/gepris/projekt/460248799

# %% [markdown]
# Let's save the parsed data into a CSV-file:

# %%
df_nfdi.T.to_csv("../../../data/GEPRIS_NFDI_project_pages.csv", index=True, index_label='gepris', encoding='utf-8')
